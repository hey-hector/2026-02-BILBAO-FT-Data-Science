# %% [markdown]
# # Python Interactive Maps with Folium

# %% [markdown]
# # Notes

# %% [markdown]
# * folium is similar to ipyleaflet but different in some functionaly and syntax
# * for install instructions go to python.org, python package index, search for folium

# %% [markdown]
# # Data Files

# %% [markdown]
# * indiana_outline_map.geojson
# * sales_region1.geojson
# * sales_region2.geojson
# * sales_region3.geojson
# * geojson_indianacounties.geojson
# * indiana_population_by_county.csv
# * flags_of_africa.png (from Wikipedia)

# %% [markdown]
# # Documentation

# %%
from IPython.display import IFrame
documentation = IFrame(src='https://python-visualization.github.io/folium/', width=1000, height=500)
display(documentation)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="https://python-visualization.github.io/folium/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# %pip install folium geocoder geopy vega_datasets
# Out:
# Collecting folium
#   Downloading folium-0.20.0-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting geocoder
#   Downloading geocoder-1.38.1-py2.py3-none-any.whl.metadata (14 kB)
# Collecting geopy
#   Downloading geopy-2.4.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting vega_datasets
#   Downloading vega_datasets-0.9.0-py3-none-any.whl.metadata (5.5 kB)
# Collecting branca>=0.6.0 (from folium)
#   Downloading branca-0.8.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\users\data_\appdata\local\programs\python\python311\lib\site-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in c:\users\data_\appdata\local\programs\python\python311\lib\site-packages (from folium) (2.4.2)
# Requirement already satisfied: requests in c:\users\data_\appdata\local\programs\python\python311\lib\site-packages (from folium) (2.32.5)
# Collecting xyzservices (from folium)
#   Downloading xyzservices-2025.11.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting click (from geocoder)
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting future (from geocoder)
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting ratelim (from geocoder)
#   Downloading ratelim-0.1.6-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six in c:\users\data_\appdata\local\programs\python\python311\lib\site-packages (from geocoder) (1.17.0)
# Collecting geographiclib<3,>=1.52 (from geopy)
#   Downloading geographiclib-2.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: pandas in c:\users\data_\appdata\local\programs\python\python311\lib\site-packages (from vega_datasets) (3.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\data_\appdata\local\programs\python\python311\lib\site-packages (from jinja2>=2.9->folium) (3.0.3)
# Requirement already satisfied: colorama in c:\users\data_\appdata\local\programs\python\python311\lib\site-packages (from click->geocoder) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\data_\appdata\local\programs\python\python311\lib\site-packages (from pandas->vega_datasets) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\data_\appdata\local\programs\python\python311\lib\site-packages (from pandas->vega_datasets) (2025.3)
# Requirement already satisfied: decorator in c:\users\data_\appdata\local\programs\python\python311\lib\site-packages (from ratelim->geocoder) (5.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\data_\appdata\local\programs\python\python311\lib\site-packages (from requests->folium) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\data_\appdata\local\programs\python\python311\lib\site-packages (from requests->folium) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\data_\appdata\local\programs\python\python311\lib\site-packages (from requests->folium) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\data_\appdata\local\programs\python\python311\lib\site-packages (from requests->folium) (2026.1.4)
# Downloading folium-0.20.0-py2.py3-none-any.whl (113 kB)
#    ---------------------------------------- 0.0/113.4 kB ? eta -:--:--
#    ---------------------------------------  112.6/113.4 kB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 113.4/113.4 kB 2.2 MB/s eta 0:00:00
# Downloading geocoder-1.38.1-py2.py3-none-any.whl (98 kB)
#    ---------------------------------------- 0.0/98.6 kB ? eta -:--:--
#    ---------------------------------------- 98.6/98.6 kB ? eta 0:00:00
# Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
#    ---------------------------------------- 0.0/125.4 kB ? eta -:--:--
#    ---------------------------------------- 125.4/125.4 kB 7.7 MB/s eta 0:00:00
# Downloading vega_datasets-0.9.0-py3-none-any.whl (210 kB)
#    ---------------------------------------- 0.0/210.8 kB ? eta -:--:--
#    --------------------------------------- 210.8/210.8 kB 12.5 MB/s eta 0:00:00
# Downloading branca-0.8.2-py3-none-any.whl (26 kB)
# Downloading geographiclib-2.1-py3-none-any.whl (40 kB)
#    ---------------------------------------- 0.0/40.7 kB ? eta -:--:--
#    ---------------------------------------- 40.7/40.7 kB ? eta 0:00:00
# Downloading click-8.3.1-py3-none-any.whl (108 kB)
#    ---------------------------------------- 0.0/108.3 kB ? eta -:--:--
#    ---------------------------------------- 108.3/108.3 kB 6.1 MB/s eta 0:00:00
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
#    ---------------------------------------- 0.0/491.3 kB ? eta -:--:--
#    --------------------------------------- 491.3/491.3 kB 10.2 MB/s eta 0:00:00
# Downloading ratelim-0.1.6-py2.py3-none-any.whl (4.0 kB)
# Downloading xyzservices-2025.11.0-py3-none-any.whl (93 kB)
#    ---------------------------------------- 0.0/93.9 kB ? eta -:--:--
#    ---------------------------------------- 93.9/93.9 kB ? eta 0:00:00
# Installing collected packages: xyzservices, ratelim, geographiclib, future, click, geopy, geocoder, branca, vega_datasets, folium
# Successfully installed branca-0.8.2 click-8.3.1 folium-0.20.0 future-1.0.0 geocoder-1.38.1 geographiclib-2.1 geopy-2.4.1 ratelim-0.1.6 vega_datasets-0.9.0 xyzservices-2025.11.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Imports

# %%
import folium # pip install folium
from folium import plugins
# import ipywidgets # pip install ipywidgets
import geocoder # pip install geocoder
# import geopy # pip install geopy
import numpy as np
import pandas as pd
from vega_datasets import data as vds # pip install vega_datasets

# %% [markdown]
# # Basic Maps

# %%
help(folium.Map)
# Out:
# Help on class Map in module folium.folium:
#
# class Map(folium.elements.JSCSSMixin, folium.map.Evented)
#  |  Map(location: Optional[Sequence[float]] = None, width: Union[str, float] = '100%', height: Union[str, float] = '100%', left: Union[str, float] = '0%', top: Union[str, float] = '0%', position: str = 'relative', tiles: Union[str, folium.raster_layers.TileLayer, NoneType] = 'OpenStreetMap', attr: Optional[str] = None, min_zoom: Optional[int] = None, max_zoom: Optional[int] = None, zoom_start: int = 10, min_lat: float = -90, max_lat: float = 90, min_lon: float = -180, max_lon: float = 180, max_bounds: bool = False, crs: str = 'EPSG3857', control_scale: bool = False, prefer_canvas: bool = False, no_touch: bool = False, disable_3d: bool = False, png_enabled: bool = False, zoom_control: Union[bool, str] = True, font_size: str = '1rem', **kwargs: Union[str, float, bool, Sequence, dict, NoneType])
#  |
#  |  Create a Map with Folium and Leaflet.js
#  |
#  |  Generate a base map of given width and height with either default
#  |  tilesets or a custom tileset URL. Folium has built-in all tilesets
#  |  available in the ``xyzservices`` package. For example, you can pass
#  |  any of the following to the "tiles" keyword:
#  |
#  |      - "OpenStreetMap"
#  |      - "CartoDB Positron"
#  |      - "CartoDB Voyager"
#  |
#  |  Explore more provider names available in ``xyzservices`` here:
#  |  https://leaflet-extras.github.io/leaflet-providers/preview/.
#  |
#  |  You can also pass a custom tileset by passing a
#  |  :class:`xyzservices.TileProvider` or a Leaflet-style
#  |  URL to the tiles parameter: ``https://{s}.yourtiles.com/{z}/{x}/{y}.png``.
#  |
#  |  Parameters
#  |  ----------
#  |  location: tuple or list, default None
#  |      Latitude and Longitude of Map (Northing, Easting).
#  |  width: pixel int or percentage string (default: '100%')
#  |      Width of the map.
#  |  height: pixel int or percentage string (default: '100%')
#  |      Height of the map.
#  |  tiles: str or TileLayer or :class:`xyzservices.TileProvider`, default 'OpenStreetMap'
#  |      Map tileset to use. Can choose from a list of built-in tiles,
#  |      pass a :class:`xyzservices.TileProvider`,
#  |      pass a custom URL, pass a TileLayer object,
#  |      or pass `None` to create a map without tiles.
#  |      For more advanced tile layer options, use the `TileLayer` class.
#  |  min_zoom: int, optional, default 0
#  |      Minimum allowed zoom level for the tile layer that is created.
#  |      Filled by xyzservices by default.
#  |  max_zoom: int, optional, default 18
#  |      Maximum allowed zoom level for the tile layer that is created.
#  |      Filled by xyzservices by default.
#  |  zoom_start: int, default 10
#  |      Initial zoom level for the map.
#  |  attr: string, default None
#  |      Map tile attribution; only required if passing custom tile URL.
#  |  crs : str, default 'EPSG3857'
#  |      Defines coordinate reference systems for projecting geographical points
#  |      into pixel (screen) coordinates and back.
#  |      You can use Leaflet's values :
#  |      * EPSG3857 : The most common CRS for online maps, used by almost all
#  |      free and commercial tile providers. Uses Spherical Mercator projection.
#  |      Set in by default in Map's crs option.
#  |      * EPSG4326 : A common CRS among GIS enthusiasts.
#  |      Uses simple Equirectangular projection.
#  |      * EPSG3395 : Rarely used by some commercial tile providers.
#  |      Uses Elliptical Mercator projection.
#  |      * Simple : A simple CRS that maps longitude and latitude into
#  |      x and y directly. May be used for maps of flat surfaces
#  |      (e.g. game maps). Note that the y axis should still be inverted
#  |      (going from bottom to top).
#  |  control_scale : bool, default False
#  |      Whether to add a control scale on the map.
#  |  prefer_canvas : bool, default False
#  |      Forces Leaflet to use the Canvas back-end (if available) for
#  |      vector layers instead of SVG. This can increase performance
#  |      considerably in some cases (e.g. many thousands of circle
#  |      markers on the map).
#  |  no_touch : bool, default False
#  |      Forces Leaflet to not use touch events even if it detects them.
#  |  disable_3d : bool, default False
#  |      Forces Leaflet to not use hardware-accelerated CSS 3D
#  |      transforms for positioning (which may cause glitches in some
#  |      rare environments) even if they're supported.
#  |  zoom_control : bool or position string, default True
#  |      Display zoom controls on the map. The default `True` places it in the top left corner.
#  |      Other options are 'topleft', 'topright', 'bottomleft' or 'bottomright'.
#  |  font_size : int or float or string (default: '1rem')
#  |      The font size to use for Leaflet, can either be a number or a
#  |      string ending in 'rem', 'em', or 'px'.
#  |  **kwargs
#  |      Additional keyword arguments are passed to Leaflets Map class:
#  |      https://leafletjs.com/reference.html#map
#  |
#  |  Returns
#  |  -------
#  |  Folium Map Object
#  |
#  |  Examples
#  |  --------
#  |  >>> m = folium.Map(location=[45.523, -122.675], width=750, height=500)
#  |  >>> m = folium.Map(location=[45.523, -122.675], tiles="cartodb positron")
#  |  >>> m = folium.Map(
#  |  ...     location=[45.523, -122.675],
#  |  ...     zoom_start=2,
#  |  ...     tiles="https://api.mapbox.com/v4/mapbox.streets/{z}/{x}/{y}.png?access_token=mytoken",
#  |  ...     attr="Mapbox attribution",
#  |  ... )
#  |
#  |  Method resolution order:
#  |      Map
#  |      folium.elements.JSCSSMixin
#  |      folium.map.Evented
#  |      folium.map.Class
#  |      branca.element.MacroElement
#  |      branca.element.Element
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, location: Optional[Sequence[float]] = None, width: Union[str, float] = '100%', height: Union[str, float] = '100%', left: Union[str, float] = '0%', top: Union[str, float] = '0%', position: str = 'relative', tiles: Union[str, folium.raster_layers.TileLayer, NoneType] = 'OpenStreetMap', attr: Optional[str] = None, min_zoom: Optional[int] = None, max_zoom: Optional[int] = None, zoom_start: int = 10, min_lat: float = -90, max_lat: float = 90, min_lon: float = -180, max_lon: float = 180, max_bounds: bool = False, crs: str = 'EPSG3857', control_scale: bool = False, prefer_canvas: bool = False, no_touch: bool = False, disable_3d: bool = False, png_enabled: bool = False, zoom_control: Union[bool, str] = True, font_size: str = '1rem', **kwargs: Union[str, float, bool, Sequence, dict, NoneType])
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  fit_bounds(self, bounds: Sequence[Sequence[float]], padding_top_left: Optional[Sequence[float]] = None, padding_bottom_right: Optional[Sequence[float]] = None, padding: Optional[Sequence[float]] = None, max_zoom: Optional[int] = None) -> None
#  |      Fit the map to contain a bounding box with the
#  |      maximum zoom level possible.
#  |
#  |      Parameters
#  |      ----------
#  |      bounds: list of (latitude, longitude) points
#  |          Bounding box specified as two points [southwest, northeast]
#  |      padding_top_left: (x, y) point, default None
#  |          Padding in the top left corner. Useful if some elements in
#  |          the corner, such as controls, might obscure objects you're zooming
#  |          to.
#  |      padding_bottom_right: (x, y) point, default None
#  |          Padding in the bottom right corner.
#  |      padding: (x, y) point, default None
#  |          Equivalent to setting both top left and bottom right padding to
#  |          the same value.
#  |      max_zoom: int, default None
#  |          Maximum zoom to be used.
#  |
#  |      Examples
#  |      --------
#  |      >>> m.fit_bounds([[52.193636, -2.221575], [52.636878, -1.139759]])
#  |
#  |  keep_in_front(self, *args: folium.map.Layer) -> None
#  |      Pass one or multiple layers that must stay in front.
#  |
#  |      The ordering matters, the last one is put on top.
#  |
#  |      Parameters
#  |      ----------
#  |      *args :
#  |          Variable length argument list. Any folium object that counts as an
#  |          overlay. For example FeatureGroup or TileLayer.
#  |          Does not work with markers, for those use z_index_offset.
#  |
#  |  show_in_browser(self) -> None
#  |      Display the Map in the default web browser.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __annotations__ = {}
#  |
#  |  default_css = [('leaflet_css', 'https://cdn.jsdelivr.net/npm/leaflet@1...
#  |
#  |  default_js = [('leaflet', 'https://cdn.jsdelivr.net/npm/leaflet@1.9.3/...
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from folium.elements.JSCSSMixin:
#  |
#  |  add_css_link(self, name: str, url: str)
#  |      Add or update css resource link.
#  |
#  |  add_js_link(self, name: str, url: str)
#  |      Add or update JS resource link.
#  |
#  |  render(self, **kwargs)
#  |      Renders the HTML representation of the element.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from folium.map.Evented:
#  |
#  |  on(self, **event_map: folium.utilities.JsCode)
#  |
#  |  once(self, **event_map: folium.utilities.JsCode)
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from folium.map.Class:
#  |
#  |  include(**kwargs)
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties inherited from folium.map.Class:
#  |
#  |  leaflet_class_name
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from folium.map.Class:
#  |
#  |  includes = {}
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from branca.element.Element:
#  |
#  |  __getstate__(self) -> dict
#  |      Modify object state when pickling the object.
#  |
#  |      jinja2 Templates cannot be pickled, so remove the instance attribute
#  |      if it exists. It will be added back when unpickling (see __setstate__).
#  |
#  |  __setstate__(self, state: dict)
#  |      Re-add _template instance attribute when unpickling
#  |
#  |  add_child(self, child: 'Element', name: Optional[str] = None, index: Optional[int] = None) -> 'Element'
#  |      Add a child.
#  |
#  |  add_children(self, child: 'Element', name: Optional[str] = None, index: Optional[int] = None) -> 'Element'
#  |      Add a child.
#  |
#  |  add_to(self, parent: 'Element', name: Optional[str] = None, index: Optional[int] = None) -> 'Element'
#  |      Add element to a parent.
#  |
#  |  get_bounds(self) -> List[List[Optional[float]]]
#  |      Computes the bounds of the object and all it's children
#  |      in the form [[lat_min, lon_min], [lat_max, lon_max]].
#  |
#  |  get_name(self) -> str
#  |      Returns a string representation of the object.
#  |      This string has to be unique and to be a python and
#  |      javascript-compatible
#  |      variable name.
#  |
#  |  get_root(self) -> 'Element'
#  |      Returns the root of the elements tree.
#  |
#  |  save(self, outfile: Union[str, bytes, pathlib.Path, BinaryIO], close_file: bool = True, **kwargs)
#  |      Saves an Element into a file.
#  |
#  |      Parameters
#  |      ----------
#  |      outfile : str or file object
#  |          The file (or filename) where you want to output the html.
#  |      close_file : bool, default True
#  |          Whether the file has to be closed after write.
#  |
#  |  to_dict(self, depth: int = -1, ordered: bool = True, **kwargs) -> Union[dict, collections.OrderedDict]
#  |      Returns a dict representation of the object.
#  |
#  |  to_json(self, depth: int = -1, **kwargs) -> str
#  |      Returns a JSON representation of the object.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from branca.element.Element:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object

# %%
folium.Map()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_273def96fec674378118bc486ae52e95 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_273def96fec674378118bc486ae52e95&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_273def96fec674378118bc486ae52e95 = L.map(
#                 &quot;map_273def96fec674378118bc486ae52e95&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_77389c1c33c9c0558c3b23465c793fcb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_77389c1c33c9c0558c3b23465c793fcb.addTo(map_273def96fec674378118bc486ae52e95);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map1 = folium.Map(location=[43.2540,-2.9230],
                 zoom_start=18,
                #  width=700,
                #  height=500,
                 control_scale=True)
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a48738ee91c528007f35bd8e7213e59b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a48738ee91c528007f35bd8e7213e59b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a48738ee91c528007f35bd8e7213e59b = L.map(
#                 &quot;map_a48738ee91c528007f35bd8e7213e59b&quot;,
#                 {
#                     center: [43.254, -2.923],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 18,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_a48738ee91c528007f35bd8e7213e59b);
#
#
#
#
#
#             var tile_layer_d7421262d02c7c74694595222a8f9ccf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d7421262d02c7c74694595222a8f9ccf.addTo(map_a48738ee91c528007f35bd8e7213e59b);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Save Map

# %%
map1.save('map1.html')

# %% [markdown]
# # Map Types

# %%
# show map types using layer control
# Layers: https://deparkes.co.uk/2016/06/10/folium-map-tiles/

# map
map_layer_control = folium.Map(location=[43.2540,-2.9230], zoom_start=12)

# add tiles to map
folium.raster_layers.TileLayer('OpenStreetMap').add_to(map_layer_control)
# folium.raster_layers.TileLayer('Stamen_Terrain').add_to(map_layer_control)
# folium.raster_layers.TileLayer('StamenToner').add_to(map_layer_control)
# folium.raster_layers.TileLayer('StamenWatercolor').add_to(map_layer_control)
folium.raster_layers.TileLayer('CartoDB Positron').add_to(map_layer_control)
folium.raster_layers.TileLayer('CartoDB Dark_Matter').add_to(map_layer_control)

# add layer control to show different maps
folium.LayerControl().add_to(map_layer_control)

# display map
map_layer_control
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c2c6c8136716f2605223c6eb5aa2a158 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c2c6c8136716f2605223c6eb5aa2a158&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c2c6c8136716f2605223c6eb5aa2a158 = L.map(
#                 &quot;map_c2c6c8136716f2605223c6eb5aa2a158&quot;,
#                 {
#                     center: [43.254, -2.923],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4e85fa6c70bb5978ba641e8c7e52bed2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4e85fa6c70bb5978ba641e8c7e52bed2.addTo(map_c2c6c8136716f2605223c6eb5aa2a158);
#
#
#             var tile_layer_607da4ecf0dc2219119b033997e88d98 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_607da4ecf0dc2219119b033997e88d98.addTo(map_c2c6c8136716f2605223c6eb5aa2a158);
#
#
#             var tile_layer_4f5d63647d1046cdb6f6c11428024abf = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4f5d63647d1046cdb6f6c11428024abf.addTo(map_c2c6c8136716f2605223c6eb5aa2a158);
#
#
#             var tile_layer_07ba37f52756bc001e07a7d79298ed86 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_07ba37f52756bc001e07a7d79298ed86.addTo(map_c2c6c8136716f2605223c6eb5aa2a158);
#
#
#             var layer_control_3c739f7a60819658ba9079e349805895_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_607da4ecf0dc2219119b033997e88d98,
#                     &quot;cartodbpositron&quot; : tile_layer_4f5d63647d1046cdb6f6c11428024abf,
#                     &quot;cartodbdarkmatter&quot; : tile_layer_07ba37f52756bc001e07a7d79298ed86,
#                 },
#                 overlays :  {
#                 },
#             };
#             let layer_control_3c739f7a60819658ba9079e349805895 = L.control.layers(
#                 layer_control_3c739f7a60819658ba9079e349805895_layers.base_layers,
#                 layer_control_3c739f7a60819658ba9079e349805895_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_c2c6c8136716f2605223c6eb5aa2a158);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_with_mini = folium.Map(location=[40.416719, -3.684016], zoom_start=7)

minimap = plugins.MiniMap(toggle_display = True)

map_with_mini.add_child(minimap)

plugins.Fullscreen(position = 'topright').add_to(map_with_mini)
map_with_mini.save('map_with_mini.html')
map_with_mini
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dd5696b7781f1b98dfb493ad0cc24186 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dd5696b7781f1b98dfb493ad0cc24186&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dd5696b7781f1b98dfb493ad0cc24186 = L.map(
#                 &quot;map_dd5696b7781f1b98dfb493ad0cc24186&quot;,
#                 {
#                     center: [40.416719, -3.684016],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fc45111c965325711a4448f905262b1e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fc45111c965325711a4448f905262b1e.addTo(map_dd5696b7781f1b98dfb493ad0cc24186);
#
#
#             var tile_layer_34216f86dee602a736f7581f6b20dbdb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detect_retina&quot;: false, &quot;max_native_zoom&quot;: 19, &quot;max_zoom&quot;: 19, &quot;min_zoom&quot;: 0, &quot;no_wrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#             var mini_map_161e8312096de45e02756998310467a2 = new L.Control.MiniMap(
#                 tile_layer_34216f86dee602a736f7581f6b20dbdb,
#                 {
#   &quot;position&quot;: &quot;bottomright&quot;,
#   &quot;width&quot;: 150,
#   &quot;height&quot;: 150,
#   &quot;collapsedWidth&quot;: 25,
#   &quot;collapsedHeight&quot;: 25,
#   &quot;zoomLevelOffset&quot;: -5,
#   &quot;centerFixed&quot;: false,
#   &quot;zoomAnimation&quot;: false,
#   &quot;toggleDisplay&quot;: true,
#   &quot;autoToggleDisplay&quot;: false,
#   &quot;minimized&quot;: false,
# }
#             );
#             map_dd5696b7781f1b98dfb493ad0cc24186.addControl(mini_map_161e8312096de45e02756998310467a2);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_dd5696b7781f1b98dfb493ad0cc24186);
#
#
#             tile_layer_fc45111c965325711a4448f905262b1e.addTo(map_dd5696b7781f1b98dfb493ad0cc24186);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Markers

# %%
help(folium.Marker)
# Out:
# Help on class Marker in module folium.map:
#
# class Marker(branca.element.MacroElement)
#  |  Marker(location: Optional[Sequence[float]] = None, popup: Union[ForwardRef('Popup'), str, NoneType] = None, tooltip: Union[ForwardRef('Tooltip'), str, NoneType] = None, icon: Union[folium.map.Icon, ForwardRef('CustomIcon'), ForwardRef('DivIcon'), NoneType] = None, draggable: bool = False, **kwargs: Union[str, float, bool, Sequence, dict, NoneType])
#  |
#  |  Create a simple stock Leaflet marker on the map, with optional
#  |  popup text or Vincent visualization.
#  |
#  |  Parameters
#  |  ----------
#  |  location: tuple or list
#  |      Latitude and Longitude of Marker (Northing, Easting)
#  |  popup: string or folium.Popup, default None
#  |      Label for the Marker; either an escaped HTML string to initialize
#  |      folium.Popup or a folium.Popup instance.
#  |  tooltip: str or folium.Tooltip, default None
#  |      Display a text when hovering over the object.
#  |  icon: Icon, CustomIcon or DivIcon, optional
#  |      the Icon plugin to use to render the marker.
#  |  draggable: bool, default False
#  |      Set to True to be able to drag the marker around the map.
#  |
#  |  Returns
#  |  -------
#  |  Marker names and HTML in obj.template_vars
#  |
#  |  Examples
#  |  --------
#  |  >>> Marker(location=[45.5, -122.3], popup="Portland, OR")
#  |  >>> Marker(location=[45.5, -122.3], popup=Popup("Portland, OR"))
#  |  # If the popup label has characters that need to be escaped in HTML
#  |  >>> Marker(
#  |  ...     location=[45.5, -122.3],
#  |  ...     popup=Popup("Mom & Pop Arrow Shop >>", parse_html=True),
#  |  ... )
#  |
#  |  Method resolution order:
#  |      Marker
#  |      branca.element.MacroElement
#  |      branca.element.Element
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, location: Optional[Sequence[float]] = None, popup: Union[ForwardRef('Popup'), str, NoneType] = None, tooltip: Union[ForwardRef('Tooltip'), str, NoneType] = None, icon: Union[folium.map.Icon, ForwardRef('CustomIcon'), ForwardRef('DivIcon'), NoneType] = None, draggable: bool = False, **kwargs: Union[str, float, bool, Sequence, dict, NoneType])
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  add_child(self, child, name=None, index=None)
#  |      Add a child.
#  |
#  |  render(self)
#  |      Renders the HTML representation of the element.
#  |
#  |  set_icon(self, icon)
#  |      Set the icon for this Marker
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  SetIcon = <class 'folium.map.Marker.SetIcon'>
#  |      Set the icon of a marker after both are created.
#  |
#  |
#  |  __annotations__ = {}
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from branca.element.Element:
#  |
#  |  __getstate__(self) -> dict
#  |      Modify object state when pickling the object.
#  |
#  |      jinja2 Templates cannot be pickled, so remove the instance attribute
#  |      if it exists. It will be added back when unpickling (see __setstate__).
#  |
#  |  __setstate__(self, state: dict)
#  |      Re-add _template instance attribute when unpickling
#  |
#  |  add_children(self, child: 'Element', name: Optional[str] = None, index: Optional[int] = None) -> 'Element'
#  |      Add a child.
#  |
#  |  add_to(self, parent: 'Element', name: Optional[str] = None, index: Optional[int] = None) -> 'Element'
#  |      Add element to a parent.
#  |
#  |  get_bounds(self) -> List[List[Optional[float]]]
#  |      Computes the bounds of the object and all it's children
#  |      in the form [[lat_min, lon_min], [lat_max, lon_max]].
#  |
#  |  get_name(self) -> str
#  |      Returns a string representation of the object.
#  |      This string has to be unique and to be a python and
#  |      javascript-compatible
#  |      variable name.
#  |
#  |  get_root(self) -> 'Element'
#  |      Returns the root of the elements tree.
#  |
#  |  save(self, outfile: Union[str, bytes, pathlib.Path, BinaryIO], close_file: bool = True, **kwargs)
#  |      Saves an Element into a file.
#  |
#  |      Parameters
#  |      ----------
#  |      outfile : str or file object
#  |          The file (or filename) where you want to output the html.
#  |      close_file : bool, default True
#  |          Whether the file has to be closed after write.
#  |
#  |  to_dict(self, depth: int = -1, ordered: bool = True, **kwargs) -> Union[dict, collections.OrderedDict]
#  |      Returns a dict representation of the object.
#  |
#  |  to_json(self, depth: int = -1, **kwargs) -> str
#  |      Returns a JSON representation of the object.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from branca.element.Element:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object

# %%
address_latlng
# Out:
# [None, None]

# %%
# geocode address and place marker on map



# get location information for address.
# place = 'Zaragoza'
# address = geocoder.osm(place)
# place = geocoder.osm('Madrid, Calle Juan de Mena, 14')
# place = 'Madrid, Hospital Ramon y Cajal'
# place = 'Madrid, Museo del Prado'
place = 'Sevilla, Expo 92'
address = geocoder.osm(place)

# address = geocoder.osm('Madrid, The Bridge')
# print(address)
# address latitude and longitude
address_latlng = [address.lat, address.lng]

# map
map_madrid = folium.Map(location=[address.lat, address.lng], zoom_start=12)

# add marker to map
folium.Marker(address_latlng,
             popup = place,
             tooltip = 'click').add_to(map_madrid)

# display map
display(map_madrid)
# Out:
# Status code 403 from https://nominatim.openstreetmap.org/search: ERROR - 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/search?q=Sevilla%2C+Expo+92&format=jsonv2&addressdetails=1&limit=1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\data_\AppData\Local\Programs\Python\Python311\Lib\site-packages\folium\utilities.py:103, in validate_location(location)
#     102 try:
# --> 103     float(coord)
#     104 except (TypeError, ValueError):
#
# TypeError: float() argument must be a string or a real number, not 'NoneType'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 20
#      17 address_latlng = [address.lat, address.lng]
#      19 # map
# ---> 20 map_madrid = folium.Map(location=[address.lat, address.lng], zoom_start=12)
#      22 # add marker to map
#      23 folium.Marker(address_latlng,
#      24              popup = place,
#      25              tooltip = 'click').add_to(map_madrid)
#
# File c:\Users\data_\AppData\Local\Programs\Python\Python311\Lib\site-packages\folium\folium.py:300, in Map.__init__(self, location, width, height, left, top, position, tiles, attr, min_zoom, max_zoom, zoom_start, min_lat, max_lat, min_lon, max_lon, max_bounds, crs, control_scale, prefer_canvas, no_touch, disable_3d, png_enabled, zoom_control, font_size, **kwargs)
#     298     zoom_start = 1
#     299 else:
# --> 300     self.location = validate_location(location)
#     302 Figure().add_child(self)
#     304 # Map Size Parameters.
#
# File c:\Users\data_\AppData\Local\Programs\Python\Python311\Lib\site-packages\folium\utilities.py:105, in validate_location(location)
#     103     float(coord)
#     104 except (TypeError, ValueError):
# --> 105     raise ValueError(
#     106         "Location should consist of two numerical values, "
#     107         f"but {coord!r} of type {type(coord)} is not convertible to float."
#     108     )
#     109 if math.isnan(float(coord)):
#     110     raise ValueError("Location values cannot contain NaNs.")
#
# ValueError: Location should consist of two numerical values, but None of type <class 'NoneType'> is not convertible to float.

# %%
# airports dataframe using vega_datasets
airports = vds.airports()
airports = airports[:25]
airports.head()
# Out:
#   iata                  name              city state country   latitude  \
# 0  00M               Thigpen       Bay Springs    MS     USA  31.953765
# 1  00R  Livingston Municipal        Livingston    TX     USA  30.685861
# 2  00V           Meadow Lake  Colorado Springs    CO     USA  38.945749
# 3  01G          Perry-Warsaw             Perry    NY     USA  42.741347
# 4  01J      Hilliard Airpark          Hilliard    FL     USA  30.688012
#
#     longitude
# 0  -89.234505
# 1  -95.017928
# 2 -104.569893
# 3  -78.052081
# 4  -81.905944

# %%
# multiple markers using dataframe
# there is an example below using apply function instead of loop

# create map
map_airports = folium.Map(location=[38, -98], zoom_start=4)

# plot airport locations
for (index, row) in airports.iterrows():
    folium.Marker(location = [row.loc['latitude'], row.loc['longitude']],
                 popup = row.loc['name'] + ' ' + row['city'],
                 tooltip = 'click').add_to(map_airports)

    
# display map    
map_airports
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e460a35f02a940c4f07aa20f8038f862 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e460a35f02a940c4f07aa20f8038f862&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e460a35f02a940c4f07aa20f8038f862 = L.map(
#                 &quot;map_e460a35f02a940c4f07aa20f8038f862&quot;,
#                 {
#                     center: [38.0, -98.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b71c4d2ec3c2716ec93d1455f7478dbc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b71c4d2ec3c2716ec93d1455f7478dbc.addTo(map_e460a35f02a940c4f07aa20f8038f862);
#
#
#             var marker_1e344d0bca04273876aab34b8e18077c = L.marker(
#                 [31.95376472, -89.23450472],
#                 {
# }
#             ).addTo(map_e460a35f02a940c4f07aa20f8038f862);
#
#
#         var popup_5412a84bdc3ca0c10f92700a2406f498 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2da036ecf06d8c4e8982263fbe68a6c = $(`&lt;div id=&quot;html_b2da036ecf06d8c4e8982263fbe68a6c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Thigpen Bay Springs&lt;/div&gt;`)[0];
#                 popup_5412a84bdc3ca0c10f92700a2406f498.setContent(html_b2da036ecf06d8c4e8982263fbe68a6c);
#
#
#
#         marker_1e344d0bca04273876aab34b8e18077c.bindPopup(popup_5412a84bdc3ca0c10f92700a2406f498)
#         ;
#
#
#
#
#             marker_1e344d0bca04273876aab34b8e18077c.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_f54acad392b5dc1eab7dbe2288d56935 = L.marker(
#                 [30.68586111, -95.01792778],
#                 {
# }
#             ).addTo(map_e460a35f02a940c4f07aa20f8038f862);
#
#
#         var popup_cb5adb0b29838de245bb62c8f5b517d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b711964f485d136e8084b36bcb4ba853 = $(`&lt;div id=&quot;html_b711964f485d136e8084b36bcb4ba853&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Livingston Municipal Livingston&lt;/div&gt;`)[0];
#                 popup_cb5adb0b29838de245bb62c8f5b517d1.setContent(html_b711964f485d136e8084b36bcb4ba853);
#
#
#
#         marker_f54acad392b5dc1eab7dbe2288d56935.bindPopup(popup_cb5adb0b29838de245bb62c8f5b517d1)
#         ;
#
#
#
#
#             marker_f54acad392b5dc1eab7dbe2288d56935.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_754c13b097cb0da4c649c544e7d2beca = L.marker(
#                 [38.94574889, -104.5698933],
#                 {
# }
#             ).addTo(map_e460a35f02a940c4f07aa20f8038f862);
#
#
#         var popup_89bfdc627abdf880869debdd6462e815 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_54ad8c66aa944ec57cc217287e7e8bef = $(`&lt;div id=&quot;html_54ad8c66aa944ec57cc217287e7e8bef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Meadow Lake Colorado Springs&lt;/div&gt;`)[0];
#                 popup_89bfdc627abdf880869debdd6462e815.setContent(html_54ad8c66aa944ec57cc217287e7e8bef);
#
#
#
#         marker_754c13b097cb0da4c649c544e7d2beca.bindPopup(popup_89bfdc627abdf880869debdd6462e815)
#         ;
#
#
#
#
#             marker_754c13b097cb0da4c649c544e7d2beca.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_6b31a8ba40b678c02e109b2219e3bd96 = L.marker(
#                 [42.74134667, -78.05208056],
#                 {
# }
#             ).addTo(map_e460a35f02a940c4f07aa20f8038f862);
#
#
#         var popup_4f64af3744a353bddd2a457aa5115d22 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3733c93bba4197d983f6b799415348b2 = $(`&lt;div id=&quot;html_3733c93bba4197d983f6b799415348b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Perry-Warsaw Perry&lt;/div&gt;`)[0];
#                 popup_4f64af3744a353bddd2a457aa5115d22.setContent(html_3733c93bba4197d983f6b799415348b2);
#
#
#
#         marker_6b31a8ba40b678c02e109b2219e3bd96.bindPopup(popup_4f64af

# %%
# markers with apply function

# map
map_airports2 = folium.Map(location=[38, -98], zoom_start=4)

# plot airport locations using apply
airports.apply(lambda row: folium.Marker(location = [row['latitude'], row['longitude']], popup = row.loc['name'] + ' ' + row['city'],).add_to(map_airports2), axis=1)

# display map
map_airports2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_73007e8851ea86541844ba51f2f1fd4c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_73007e8851ea86541844ba51f2f1fd4c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_73007e8851ea86541844ba51f2f1fd4c = L.map(
#                 &quot;map_73007e8851ea86541844ba51f2f1fd4c&quot;,
#                 {
#                     center: [38.0, -98.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_22b439c4a91bea762f58528984a68e70 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_22b439c4a91bea762f58528984a68e70.addTo(map_73007e8851ea86541844ba51f2f1fd4c);
#
#
#             var marker_17a0473915449792a5a903106e85e3e2 = L.marker(
#                 [31.95376472, -89.23450472],
#                 {
# }
#             ).addTo(map_73007e8851ea86541844ba51f2f1fd4c);
#
#
#         var popup_b525a2365c6c527875b1edaba9b1e163 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f2a6b668ad5b07586ee651f1c07fa7b = $(`&lt;div id=&quot;html_0f2a6b668ad5b07586ee651f1c07fa7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Thigpen Bay Springs&lt;/div&gt;`)[0];
#                 popup_b525a2365c6c527875b1edaba9b1e163.setContent(html_0f2a6b668ad5b07586ee651f1c07fa7b);
#
#
#
#         marker_17a0473915449792a5a903106e85e3e2.bindPopup(popup_b525a2365c6c527875b1edaba9b1e163)
#         ;
#
#
#
#
#             var marker_4bcca5d884e8b030cd71ce60b82ba5f0 = L.marker(
#                 [30.68586111, -95.01792778],
#                 {
# }
#             ).addTo(map_73007e8851ea86541844ba51f2f1fd4c);
#
#
#         var popup_b127591fca8ca11d68f671903cab04c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fbc0e7ec312349075b73e0658734bbea = $(`&lt;div id=&quot;html_fbc0e7ec312349075b73e0658734bbea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Livingston Municipal Livingston&lt;/div&gt;`)[0];
#                 popup_b127591fca8ca11d68f671903cab04c0.setContent(html_fbc0e7ec312349075b73e0658734bbea);
#
#
#
#         marker_4bcca5d884e8b030cd71ce60b82ba5f0.bindPopup(popup_b127591fca8ca11d68f671903cab04c0)
#         ;
#
#
#
#
#             var marker_75fc90914651db90220edd320e091118 = L.marker(
#                 [38.94574889, -104.5698933],
#                 {
# }
#             ).addTo(map_73007e8851ea86541844ba51f2f1fd4c);
#
#
#         var popup_5e96161803e0dc1e24ecf24d00ada93c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_61131b0d262372ddc11e5e896109f28d = $(`&lt;div id=&quot;html_61131b0d262372ddc11e5e896109f28d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Meadow Lake Colorado Springs&lt;/div&gt;`)[0];
#                 popup_5e96161803e0dc1e24ecf24d00ada93c.setContent(html_61131b0d262372ddc11e5e896109f28d);
#
#
#
#         marker_75fc90914651db90220edd320e091118.bindPopup(popup_5e96161803e0dc1e24ecf24d00ada93c)
#         ;
#
#
#
#
#             var marker_68efa60b47e24b5c38dc95977f415b03 = L.marker(
#                 [42.74134667, -78.05208056],
#                 {
# }
#             ).addTo(map_73007e8851ea86541844ba51f2f1fd4c);
#
#
#         var popup_0d6519fa86b6a3f511f30e8d4e63c9d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f4725733455b9d1d824c805823dcc851 = $(`&lt;div id=&quot;html_f4725733455b9d1d824c805823dcc851&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Perry-Warsaw Perry&lt;/div&gt;`)[0];
#                 popup_0d6519fa86b6a3f511f30e8d4e63c9d7.setContent(html_f4725733455b9d1d824c805823dcc851);
#
#
#
#         marker_68efa60b47e24b5c38dc95977f415b03.bindPopup(popup_0d6519fa86b6a3f511f30e8d4e63c9d7)
#         ;
#
#
#
#
#             var marker_9343de4967e9b286b1e2e6062f08af7a = L.marker(
#                 [30.6880125, -81.90594389],
#                 {
# }
#             ).addTo(map_73007e8851ea86541844ba51f2f1fd4c);
#
#
#         var popup_a2292cc1d124aa301a42b5bf99ae2ca3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_13d60e0f328fec458b477669e39f70e6 = $(`&lt;div id=&quot;html_13d60e0f328fec458b477669e39f70e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hilliard Airpark Hilliard&lt;/div&gt;`)[0];
#                 popup_a2292cc1d124aa301a42b5bf99ae2ca3.setContent(html_13d6

# %%
markers_dict = {'Los Angeles': [34.041008, -118.246653], 
                'Las Vegas': [36.169726, -115.143996], 
                'Denver': [39.739448, -104.992450], 
                'Chicago': [41.878765, -87.643267], 
                'Manhattan': [40.782949, -73.969559]}

# %%
for elemento in markers_dict.items():
    print(elemento)
    # print(elemento[0])
    # print(elemento[1])
# Out:
# ('Los Angeles', [34.041008, -118.246653])
# ('Las Vegas', [36.169726, -115.143996])
# ('Denver', [39.739448, -104.99245])
# ('Chicago', [41.878765, -87.643267])
# ('Manhattan', [40.782949, -73.969559])

# %%
# multiple markers using dictionary

markers_dict = {'Los Angeles': [34.041008, -118.246653], 
                'Las Vegas': [36.169726, -115.143996], 
                'Denver': [39.739448, -104.992450], 
                'Chicago': [41.878765, -87.643267], 
                'Manhattan': [40.782949, -73.969559]}

# create map
map_cities = folium.Map(location=[41, -99], zoom_start=4)

# plot locations
for i in markers_dict.items():
    folium.Marker(location=i[1], popup=i[0]).add_to(map_cities)
    print(i)

# display map    
map_cities
# Out:
# ('Los Angeles', [34.041008, -118.246653])
# ('Las Vegas', [36.169726, -115.143996])
# ('Denver', [39.739448, -104.99245])
# ('Chicago', [41.878765, -87.643267])
# ('Manhattan', [40.782949, -73.969559])
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7781039d283d89d69d1f115fdd12ba8d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7781039d283d89d69d1f115fdd12ba8d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7781039d283d89d69d1f115fdd12ba8d = L.map(
#                 &quot;map_7781039d283d89d69d1f115fdd12ba8d&quot;,
#                 {
#                     center: [41.0, -99.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ebb054683828927c4efc871331822103 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ebb054683828927c4efc871331822103.addTo(map_7781039d283d89d69d1f115fdd12ba8d);
#
#
#             var marker_d8ca4ca9bec95a70864e7577a2d2ce00 = L.marker(
#                 [34.041008, -118.246653],
#                 {
# }
#             ).addTo(map_7781039d283d89d69d1f115fdd12ba8d);
#
#
#         var popup_fc2fea69de5fc7a8cd38d7f73e96fdf0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b9959f1b9ece131d9812ca687ddb9d10 = $(`&lt;div id=&quot;html_b9959f1b9ece131d9812ca687ddb9d10&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Los Angeles&lt;/div&gt;`)[0];
#                 popup_fc2fea69de5fc7a8cd38d7f73e96fdf0.setContent(html_b9959f1b9ece131d9812ca687ddb9d10);
#
#
#
#         marker_d8ca4ca9bec95a70864e7577a2d2ce00.bindPopup(popup_fc2fea69de5fc7a8cd38d7f73e96fdf0)
#         ;
#
#
#
#
#             var marker_914f29de2290c52f8453ce799c01e2c6 = L.marker(
#                 [36.169726, -115.143996],
#                 {
# }
#             ).addTo(map_7781039d283d89d69d1f115fdd12ba8d);
#
#
#         var popup_5c7bdd87d5a2c95aec24d9ceb03d4619 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_49b4c7122ba42b09361390984e68348d = $(`&lt;div id=&quot;html_49b4c7122ba42b09361390984e68348d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Las Vegas&lt;/div&gt;`)[0];
#                 popup_5c7bdd87d5a2c95aec24d9ceb03d4619.setContent(html_49b4c7122ba42b09361390984e68348d);
#
#
#
#         marker_914f29de2290c52f8453ce799c01e2c6.bindPopup(popup_5c7bdd87d5a2c95aec24d9ceb03d4619)
#         ;
#
#
#
#
#             var marker_39a1119c1aa51348fbfd3779f1e106c8 = L.marker(
#                 [39.739448, -104.99245],
#                 {
# }
#             ).addTo(map_7781039d283d89d69d1f115fdd12ba8d);
#
#
#         var popup_bc4546191775ecbaa447c3557c03246b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3dbc23d5e7000d917e269a62f5c1df1d = $(`&lt;div id=&quot;html_3dbc23d5e7000d917e269a62f5c1df1d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Denver&lt;/div&gt;`)[0];
#                 popup_bc4546191775ecbaa447c3557c03246b.setContent(html_3dbc23d5e7000d917e269a62f5c1df1d);
#
#
#
#         marker_39a1119c1aa51348fbfd3779f1e106c8.bindPopup(popup_bc4546191775ecbaa447c3557c03246b)
#         ;
#
#
#
#
#             var marker_b486f94f9d7635bd93515be53fdb911f = L.marker(
#                 [41.878765, -87.643267],
#                 {
# }
#             ).addTo(map_7781039d283d89d69d1f115fdd12ba8d);
#
#
#         var popup_6c916fcdd6454fccd57ed7ddc0d60657 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e91819a86257c0f6b5c06bf04f5c039a = $(`&lt;div id=&quot;html_e91819a86257c0f6b5c06bf04f5c039a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Chicago&lt;/div&gt;`)[0];
#                 popup_6c916fcdd6454fccd57ed7ddc0d60657.setContent(html_e91819a86257c0f6b5c06bf04f5c039a);
#
#
#
#         marker_b486f94f9d7635bd93515be53fdb911f.bindPopup(popup_6c916fcdd6454fccd57ed7ddc0d60657)
#         ;
#
#
#
#
#             var marker_59c94d6218ea04b3a2bad22086cf60c4 = L.marker(
#                 [40.782949, -73.969559],
#                 {
# }
#             ).addTo(map_7781039d283d89d69d1f115fdd12ba8d);
#
#
#         var popup_95aa859af85ad06ec9df3e1a4d89ae62 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6455d9a1b85e99b5cecef4a7ab55cc19 = $(`&lt;div id=&quot;html_6455d9a1b85e99b5cecef4a7ab55cc19&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Manhattan&lt;/div&gt;`)[0];
#                 popup_95aa859af85ad06ec9df3e1a4d89ae62.setContent(html_6455d9a1b85e99b5cecef4a7ab55cc19);
#
#
#
#         marker_59c94d6218ea04b3a2bad22086c

# %% [markdown]
# # Custom Markers

# %%
help(folium.Icon)
# Out:
# Help on class Icon in module folium.map:
#
# class Icon(branca.element.MacroElement)
#  |  Icon(color: str = 'blue', icon_color: str = 'white', icon: str = 'info-sign', angle: int = 0, prefix: str = 'glyphicon', **kwargs: Union[str, float, bool, Sequence, dict, NoneType])
#  |
#  |  Creates an Icon object that will be rendered
#  |  using Leaflet.awesome-markers.
#  |
#  |  Parameters
#  |  ----------
#  |  color : str, default 'blue'
#  |      The color of the marker. You can use:
#  |
#  |          ['red', 'blue', 'green', 'purple', 'orange', 'darkred',
#  |           'lightred', 'beige', 'darkblue', 'darkgreen', 'cadetblue',
#  |           'darkpurple', 'white', 'pink', 'lightblue', 'lightgreen',
#  |           'gray', 'black', 'lightgray']
#  |
#  |  icon_color : str, default 'white'
#  |      The color of the drawing on the marker. You can use colors above,
#  |      or an html color code.
#  |  icon : str, default 'info-sign'
#  |      The name of the marker sign.
#  |      See Font-Awesome website to choose yours.
#  |      Warning : depending on the icon you choose you may need to adapt
#  |      the `prefix` as well.
#  |  angle : int, default 0
#  |      The icon will be rotated by this amount of degrees.
#  |  prefix : str, default 'glyphicon'
#  |      The prefix states the source of the icon. 'fa' for font-awesome or
#  |      'glyphicon' for bootstrap 3.
#  |
#  |  https://github.com/lvoogdt/Leaflet.awesome-markers
#  |
#  |  Method resolution order:
#  |      Icon
#  |      branca.element.MacroElement
#  |      branca.element.Element
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, color: str = 'blue', icon_color: str = 'white', icon: str = 'info-sign', angle: int = 0, prefix: str = 'glyphicon', **kwargs: Union[str, float, bool, Sequence, dict, NoneType])
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __annotations__ = {}
#  |
#  |  color_options = {'beige', 'black', 'blue', 'cadetblue', 'darkblue', 'd...
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from branca.element.MacroElement:
#  |
#  |  render(self, **kwargs)
#  |      Renders the HTML representation of the element.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from branca.element.Element:
#  |
#  |  __getstate__(self) -> dict
#  |      Modify object state when pickling the object.
#  |
#  |      jinja2 Templates cannot be pickled, so remove the instance attribute
#  |      if it exists. It will be added back when unpickling (see __setstate__).
#  |
#  |  __setstate__(self, state: dict)
#  |      Re-add _template instance attribute when unpickling
#  |
#  |  add_child(self, child: 'Element', name: Optional[str] = None, index: Optional[int] = None) -> 'Element'
#  |      Add a child.
#  |
#  |  add_children(self, child: 'Element', name: Optional[str] = None, index: Optional[int] = None) -> 'Element'
#  |      Add a child.
#  |
#  |  add_to(self, parent: 'Element', name: Optional[str] = None, index: Optional[int] = None) -> 'Element'
#  |      Add element to a parent.
#  |
#  |  get_bounds(self) -> List[List[Optional[float]]]
#  |      Computes the bounds of the object and all it's children
#  |      in the form [[lat_min, lon_min], [lat_max, lon_max]].
#  |
#  |  get_name(self) -> str
#  |      Returns a string representation of the object.
#  |      This string has to be unique and to be a python and
#  |      javascript-compatible
#  |      variable name.
#  |
#  |  get_root(self) -> 'Element'
#  |      Returns the root of the elements tree.
#  |
#  |  save(self, outfile: Union[str, bytes, pathlib.Path, BinaryIO], close_file: bool = True, **kwargs)
#  |      Saves an Element into a file.
#  |
#  |      Parameters
#  |      ----------
#  |      outfile : str or file object
#  |          The file (or filename) where you want to output the html.
#  |      close_file : bool, default True
#  |          Whether the file has to be closed after write.
#  |
#  |  to_dict(self, depth: int = -1, ordered: bool = True, **kwargs) -> Union[dict, collections.OrderedDict]
#  |      Returns a dict representation of the object.
#  |
#  |  to_json(self, depth: int = -1, **kwargs) -> str
#  |      Returns a JSON representation of the object.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from branca.element.Element:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object

# %%
# map
map_cm_fa = folium.Map(location=[38, -98], zoom_start=4)

'''
Iconos 'fa'
Iconos 'glyphicon'
'''
# add custom marker to map
folium.Marker(location=[38, -98], 
              popup='popup', 
              icon=folium.Icon(color='green', icon='bolt', prefix='fa')).add_to(map_cm_fa)

# display map
map_cm_fa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c3130a9f27e94e8ab019d79e43ddf65b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c3130a9f27e94e8ab019d79e43ddf65b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c3130a9f27e94e8ab019d79e43ddf65b = L.map(
#                 &quot;map_c3130a9f27e94e8ab019d79e43ddf65b&quot;,
#                 {
#                     center: [38.0, -98.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8922d60d110e0ef9b002987bb2eb763f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8922d60d110e0ef9b002987bb2eb763f.addTo(map_c3130a9f27e94e8ab019d79e43ddf65b);
#
#
#             var marker_4e9ba7aaa010103f32a2409a2ef4fd34 = L.marker(
#                 [38.0, -98.0],
#                 {
# }
#             ).addTo(map_c3130a9f27e94e8ab019d79e43ddf65b);
#
#
#             var icon_eda691c4e491e2a65a75968697d8d895 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;bolt&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_5d960e55f2889e61ec75132e6bde6018 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1db63e61d0b783b6311b0ba85cdb1d83 = $(`&lt;div id=&quot;html_1db63e61d0b783b6311b0ba85cdb1d83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;popup&lt;/div&gt;`)[0];
#                 popup_5d960e55f2889e61ec75132e6bde6018.setContent(html_1db63e61d0b783b6311b0ba85cdb1d83);
#
#
#
#         marker_4e9ba7aaa010103f32a2409a2ef4fd34.bindPopup(popup_5d960e55f2889e61ec75132e6bde6018)
#         ;
#
#
#
#
#                 marker_4e9ba7aaa010103f32a2409a2ef4fd34.setIcon(icon_eda691c4e491e2a65a75968697d8d895);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# search for 'glyphicon bootstrap' icons to see examples

# map
map_cm_glyphicon = folium.Map(location=[38, -98], zoom_start=4)

# add custom marker to map
folium.Marker(location=[38, -98], 
              popup='popup', 
              icon=folium.Icon(icon='glyphicon-plane', prefix='glyphicon')).add_to(map_cm_glyphicon)

# display map
map_cm_glyphicon
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5e01a1869238840cd6757d0a86c59264 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5e01a1869238840cd6757d0a86c59264&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5e01a1869238840cd6757d0a86c59264 = L.map(
#                 &quot;map_5e01a1869238840cd6757d0a86c59264&quot;,
#                 {
#                     center: [38.0, -98.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0162a81063a4932f9d75d0a7e0b0d8bf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0162a81063a4932f9d75d0a7e0b0d8bf.addTo(map_5e01a1869238840cd6757d0a86c59264);
#
#
#             var marker_98ad511121dda41b12b0797e9a74426f = L.marker(
#                 [38.0, -98.0],
#                 {
# }
#             ).addTo(map_5e01a1869238840cd6757d0a86c59264);
#
#
#             var icon_8ba2bbb6a4a1814834dbf2c32021331a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;glyphicon-plane&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_615516010ea012cbad680c705e23c850 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_527e072705305fbaa58190b83307d1fb = $(`&lt;div id=&quot;html_527e072705305fbaa58190b83307d1fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;popup&lt;/div&gt;`)[0];
#                 popup_615516010ea012cbad680c705e23c850.setContent(html_527e072705305fbaa58190b83307d1fb);
#
#
#
#         marker_98ad511121dda41b12b0797e9a74426f.bindPopup(popup_615516010ea012cbad680c705e23c850)
#         ;
#
#
#
#
#                 marker_98ad511121dda41b12b0797e9a74426f.setIcon(icon_8ba2bbb6a4a1814834dbf2c32021331a);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# multiple custom markers

# dataframe with custom marker names
cm_df = pd.DataFrame({'city': ['Los Angeles', 'Las Vegas', 'Denver', 'Chicago', 'Manhattan'],
                      'latitude': [34.041008, 36.169726, 39.739448, 41.878765, 40.782949],
                      'longitude': [-118.246653, -115.143996, -104.992450, -87.643267, -73.969559],
                      'icon': ['bicycle', 'car', 'bus', 'truck', 'motorcycle']})
cm_df

# %%
# map
map_cm_multiple = folium.Map(location=[38, -98], zoom_start=4)

# add markers to map
# for loop with itertuples (experiment that appears to work well)
# can also use iterrows or dataframe apply

for i in cm_df.itertuples():
    folium.Marker(location=[i.latitude, i.longitude], 
                  popup=i.city,
                  icon=folium.Icon(icon=i.icon, prefix='fa')).add_to(map_cm_multiple)

# display map    
map_cm_multiple

# %%
# cm_enum_df.head()

# %%
# enumerate markers

# data
cm_enum_df = pd.DataFrame({'city': ['Los Angeles', 'Las Vegas', 'Denver', 'Chicago', 'Manhattan'],
                           'latitude': [34.041008, 36.169726, 39.739448, 41.878765, 40.782949],
                           'longitude': [-118.246653, -115.143996, -104.992450, -87.643267, -73.969559],
                           'icon_num': [1, 2, 3, 4, 5]})

# map
map_enum_icons = folium.Map([38, -98], zoom_start=4)

# icons using plugins.BeautifyIcon
for i in cm_enum_df.itertuples():
    folium.Marker(location=[i.latitude, i.longitude],
                  popup=i.city,
                  icon=plugins.BeautifyIcon(number=i.icon_num,
                                            border_color='blue',
                                            border_width=1,
                                            text_color='red',
                                            inner_icon_style='margin-top:0px;')).add_to(map_enum_icons)

# display map    
map_enum_icons

# %% [markdown]
# # Circle Markers

# %%
# map
map_circle = folium.Map(location=[38, -98], zoom_start=4)

# radius of the circle in meters
folium.Circle(radius = 100000, location = [38, -98], color = 'green').add_to(map_circle)

# circle of a fixed size with radius specified in pixels
folium.CircleMarker(location=[39, -105], radius = 25, color = 'blue', fill_color = 'yellow').add_to(map_circle)

# display map
map_circle

# %% [markdown]
# # Plot Route

# %%
# route

# map
map_plot_route = folium.Map(location=[38, -98], zoom_start=4)

# route_locs = ['Los Angeles', 'Las Vegas', 'Denver', 'Chicago', 'Manhattan']
# can use list of lists or list of tuples
route_lats_longs = [[34.041008,-118.246653],
                    [36.169726,-115.143996], 
                    [39.739448,-104.992450], 
                    [41.878765,-87.643267], 
                    [40.782949,-73.969559]]

# add route to map
folium.PolyLine(route_lats_longs).add_to(map_plot_route)

# display map
map_plot_route

# %%
# ant path route
# uses import - from folium import plugins

# map
map_ant_route = folium.Map(location=[38, -98], zoom_start=4)

# add ant path route to map
plugins.AntPath(route_lats_longs).add_to(map_ant_route)

# display map
map_ant_route

# %% [markdown]
# # Overlay GeoJSON Layers

# %%
# use a link or file
# use geojson.io to create custom geojson files
# can also use folium Draw control to create geojson files (example below)
# convert shapefiles to geojson using QGIS

# map
map_geojson = folium.Map(location=[39.77, -86.15], zoom_start=7)

# add geojson file to map
folium.GeoJson('data/indiana_outline_map.geojson', name='geojson indiana').add_to(map_geojson)

# # add layer control to map (allows layer to be turned on or off)
folium.LayerControl().add_to(map_geojson)

# display map
map_geojson

# %% [markdown]
# # Subgroups with GeoJSON

# %%
# map
map_with_subgroups = folium.Map(location=[39.77, -86.15], zoom_start=7)

# all subgroups
all_subgroups = folium.FeatureGroup(name='all sales regions')
map_with_subgroups.add_child(all_subgroups)

# subgroup 1
sales_region1 = plugins.FeatureGroupSubGroup(all_subgroups, 'sales region 1')
map_with_subgroups.add_child(sales_region1)

# subgroup 2
sales_region2 = plugins.FeatureGroupSubGroup(all_subgroups, 'sales region 2')
map_with_subgroups.add_child(sales_region2)

# subgroup 3
sales_region3 = plugins.FeatureGroupSubGroup(all_subgroups, 'sales region 3')
map_with_subgroups.add_child(sales_region3)

# pull in geojson layers and add to map
folium.GeoJson('data/sales_region1.geojson').add_to(sales_region1)
folium.GeoJson('data/sales_region2.geojson').add_to(sales_region2)
folium.GeoJson('data/sales_region3.geojson').add_to(sales_region3)

# add layer control to map (allows layers to be turned on or off)
folium.LayerControl(collapsed=False).add_to(map_with_subgroups)

# display map
map_with_subgroups

# %% [markdown]
# # Choropleth Map

# %%
help(folium.Choropleth)

# %%
import json

# load geo_json
# shapefiles can be converted to geojson with QGIS
with open('data/geojson_indiana_counties.geojson') as f:
    geo_json_counties = json.load(f)
    
for i in geo_json_counties['features']:
    i['id'] = i['properties']['NAME_L']

# %%
i

# %%
geo_json_counties['features'][0]

# %%
pop_df = pd.read_csv('data/indiana_population_by_county.csv')
pop_df[pop_df['County'] == 'Steuben']
pop_df

# %%
# more examples for choropleth maps in the documentation

import json

# load geo_json
# shapefiles can be converted to geojson with QGIS
with open('data/geojson_indiana_counties.geojson') as f:
    geo_json_counties = json.load(f)
    
# add feature 'id' county name to geojson
# access features
for i in geo_json_counties['features']:
    i['id'] = i['properties']['NAME_L']
    
# load data associated with geo_json
pop_df = pd.read_csv('data/indiana_population_by_county.csv')

# map    
map_choropleth = folium.Map(location=[39.77, -86.15], zoom_start=7)

# choropleth
folium.Choropleth(
    geo_data=geo_json_counties,
    name='choropleth',
    data=pop_df,
    columns=['County', 'Population'],
    # see folium.Choropleth? for details on key_on
    key_on='feature.id',
    fill_color='YlGn',
    fill_opacity=0.5,
    line_opacity=0.5,
    legend_name='Population',
    highlight=True
).add_to(map_choropleth)

# layer control to turn choropleth on or off
folium.LayerControl().add_to(map_choropleth)

# display map
map_choropleth

# %% [markdown]
# # Heat Map

# %%
# use import geocoder

# get location data for large cities (latitude and longitude)
new_york_city = geocoder.osm('New York City, New York')
los_angeles = geocoder.osm('Los Angeles, California')
chicago = geocoder.osm('Chicago, Illinois')
houston = geocoder.osm('Houston, Texas')
phoenix = geocoder.osm('Phoenix, Arizona')
philadelphia = geocoder.osm('Philadelphia, Pennsylvania')
san_antonio = geocoder.osm('San Antonio, Texas')
san_diego = geocoder.osm('San Diego, California')
dallas = geocoder.osm('Dallas, Texas')
san_jose = geocoder.osm('San Jose, California')

# create latitude, longitude, intensity for heat map
# intensity is population scaled down so heat dots are more readable
new_york_city_latlng = [new_york_city.lat, new_york_city.lng, 8398748/1000]
los_angeles_latlng = [los_angeles.lat, los_angeles.lng, 3990456/1000]
chicago_latlng = [chicago.lat, chicago.lng, 2705994/1000]
houston_latlng = [houston.lat, houston.lng, 2325502/1000]
phoenix_latlng = [phoenix.lat, phoenix.lng, 1660272/1000]
philadelphia_latlng = [philadelphia.lat, philadelphia.lng, 1584138/1000]
san_antonio_latlng = [san_antonio.lat, san_antonio.lng, 1532233/1000]
san_diego_latlng = [san_diego.lat, san_diego.lng, 1425976/1000]
dallas_latlng = [dallas.lat, dallas.lng, 1345047/1000]
san_jose_latlng = [san_jose.lat, san_jose.lng, 1030119/1000]

# create list of cities with latitude, longitude, intensity
large_cities = [new_york_city_latlng, los_angeles_latlng, chicago_latlng, houston_latlng, phoenix_latlng, 
                philadelphia_latlng, san_antonio_latlng, san_diego_latlng, dallas_latlng, san_jose_latlng]

map_heatmap = folium.Map([40, -99], tiles='CartoDB Positron', zoom_start=4)

plugins.HeatMap(large_cities).add_to(map_heatmap)

map_heatmap

# %%
help(plugins.HeatMapWithTime)

# %%
# len(heatmap_time_data)

# %%
# heatmap_time_dates

# %%
# heat map over time

# data
# take note of data format needed for heat map with time (using plugins.HeatMapWithTime?)
heatmap_time_data = (np.random.random((100,20,2)) + np.array([[39, -98]])).tolist()

# dates
heatmap_time_dates = [d.strftime('%Y-%m-%d') for d in pd.date_range('20160101', periods=len(heatmap_time_data))]

# map
map_heatmap_time = folium.Map([39, -98], tiles='CartoDB Dark_Matter', zoom_start=6)

# heatmap plugin
heatmap_time_plugin = plugins.HeatMapWithTime(heatmap_time_data, index=heatmap_time_dates)

# add heatmap plugin to map
heatmap_time_plugin.add_to(map_heatmap_time)

# display map
map_heatmap_time

# %% [markdown]
# # Latitude and Longitude Tool

# %%
# map
map_lat_long = folium.Map(location=[38, -98], zoom_start=4)

# add latitude and longitude tool to map
map_lat_long.add_child(folium.LatLngPopup())

# display map
map_lat_long

# %% [markdown]
# # Measure Control

# %%
# map
map_measure = folium.Map([40, -100], zoom_start=4)

# measure control
measure_control = plugins.MeasureControl(position='topleft', 
                                         active_color='red', 
                                         completed_color='red', 
                                         primary_length_unit='meters')

# add measure control to map
map_measure.add_child(measure_control)

# display map
map_measure

# %%
help(plugins.MeasureControl)

# %% [markdown]
# # Dual Map

# %%
# dual map
map_dual = plugins.DualMap(location=[40, -98], tiles=None, zoom_start=4)

# map tiles
folium.TileLayer('Stamen Terrain').add_to(map_dual)
folium.TileLayer('CartoDB Positron').add_to(map_dual)

# add layer control to maps
folium.LayerControl().add_to(map_dual)

# display map(s)
map_dual

# %% [markdown]
# # Draw

# %%
# map
map_draw = folium.Map(location=[40, -99], zoom_start=4)

# draw tools
# export=True exports the drawn shapes as a geojson file
draw = plugins.Draw(export=True)

# add draw tools to map
draw.add_to(map_draw)

# display map
map_draw

# %%
help(plugins.Draw)

# %% [markdown]
# # Overlay Image

# %%
# map
# map of Africa flags from Wikipedia
map_img_overlay = folium.Map([2,22], zoom_start=3, tiles='CartoDB Positron')

# image to overlay on map
img_overlay = folium.raster_layers.ImageOverlay(name='flags of Africa', 
                                                image='data/flags_of_africa.png',
                                                # bounds - [[lat_min, lon_min], [lat_max, lon_max]]
                                                bounds=[[-38, -28], [40, 60]],
                                                opacity=0.5)
# add image to map
img_overlay.add_to(map_img_overlay)

# layer control to click layer on or off
folium.LayerControl().add_to(map_img_overlay)

# display map
map_img_overlay

# %% [markdown]
# # Spain Choropleth

# %%
# MAPA DE TOTAL DE DECESOS 
import pandas as pd
data_total_mean = pd.read_csv('data/decesos_espania.csv', sep=';')
 
# Initialize the map:
m = folium.Map(location=[42.1257, -8], zoom_start = 5)

# add tile layers to the map
# con esto posibilito que luego en el mapa pueda elegir el 'tipo de vista'
tiles = ['stamenwatercolor','cartodbpositron','openstreetmap','stamenterrain']
for tile in tiles:
    folium.TileLayer(tile).add_to(m)
    
 
# Add the color for the chloropleth:
m.choropleth(
 geo_data='data/provincias-espanolas 2.0.geojson',
 name='choropleth',
 data=data_total_mean,
 columns=['Comunidad Autónoma', 'Todas las causas'],
 key_on='feature.properties.ccaa',   # dentro del 'geojson', viendo su estructura de datos
 fill_color='BuPu',
 fill_opacity=0.7,
 line_opacity=0.2,
 legend_name='Decesos por comunidad autonoma'
)
folium.LayerControl().add_to(m)

m
